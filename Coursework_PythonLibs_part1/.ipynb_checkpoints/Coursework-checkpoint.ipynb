# %% [markdown]
# # My coursework

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
matplotlib.rcParams.update({'font.size': 14})  # размер шрифта на графиках

# %%
dataset = pd.read_csv('train.csv', delimiter=',')
dataset
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 0     14038          35    2.0   47.981561   29.442751            6.0      7
# 1     15053          41    3.0   65.683640   40.049543            8.0      7
# 2      4765          53    2.0   44.947953   29.197612            0.0      8
# 3      5809          58    2.0   53.352981   52.731512            9.0      8
# 4     10783          99    1.0   39.649192   23.776169            7.0     11
# 5     12915          59    3.0   80.384479   46.683720           12.0      5
# 6     14549         154    2.0   62.254114   37.160377            7.0      3
# 7     11993          74    2.0   80.312926         NaN            0.0     14
# 8      5172           1    2.0   64.511437         NaN            1.0      9
# 9      8649          23    1.0   46.461409   18.915552            8.0     13
# 10    15370          28    2.0   46.304907   27.922584            6.0      8
# 11    12427          31    3.0   68.808859   45.736906            7.0      1
# 12     6452          13    2.0   54.522805   31.759753            1.0      8
# 13     2408          57    3.0   68.102739   39.311493            8.0      6
# 14    10953          27    1.0   53.769097   52.408027            1.0      5
# 15     2823          85    3.0   73.612225   53.892089            6.0      4
# 16     2119          27    2.0   49.360648   31.993964            5.0      6
# 17     3000          34    2.0   57.969964   32.012483            9.0      6
# 18     2829          57    1.0   44.513481   23.113423            8.0      6
# 19     4909          19    3.0  110.959792   56.996765           11.0     16
# 20     8862           0    3.0  103.605292   47.799426           10.0     12
# 21    11935          27    2.0   64.711835         NaN            1.0     15
# 22    11852          48    1.0   41.668650   20.207762           10.0     19
# 23     6641          54    3.0  118.907612         NaN            0.0      2
# 24     7704         150    3.0   62.180536   44.169694            5.0      4
# 25     5073          74    2.0   82.667915         NaN            1.0     16
# 26     4378          27    3.0  106.958871    0.641822            0.0     17
# 27     7550          23    2.0   64.556209         NaN            1.0      8
# 28     8054          23    1.0   42.530043   43.967759            1.0      3
# 29      522          11    2.0   48.372232   31.007581            6.0      4
# ...     ...         ...    ...         ...         ...            ...    ...
# 9970   1612          84    3.0   53.430413   34.603687            6.0      8
# 9971  16050          67    2.0   58.629682   36.330029            9.0     19
# 9972   6097           6    3.0   82.147338         NaN            1.0     17
# 9973  12590         115    2.0   48.201451   33.396431            8.0     15
# 9974   2159          30    1.0   33.227093   32.639166            1.0      4
# 9975   5071          27    2.0   60.055527         NaN           12.0     16
# 9976   3621          22    2.0   58.853794         NaN            1.0     10
# 9977  10650          54    2.0   38.599779   22.740244            6.0      2
# 9978  13725           1    2.0   67.510526         NaN            1.0     10
# 9979  12758          64    2.0   56.203601   34.292901            8.0     13
# 9980  15654          10    2.0   49.975125   32.786612            6.0      5
# 9981  13352          77    2.0   53.537800   30.979054            8.0     10
# 9982  12805           8    1.0   39.195153   22.158768            9.0     12
# 9983   2705           6    2.0   64.311707   61.920700            1.0     12
# 9984   2237          52    3.0   64.074977   47.633428            6.0     11
# 9985  16159          27    1.0   38.968338         NaN            1.0     10
# 9986   2996           1    2.0   64.994245         NaN            1.0      9
# 9987  15623          23    2.0   55.620092         NaN            0.0      2
# 9988  14025          53    2.0   54.167124   33.766477            8.0      5
# 9989   4145          96    3.0   90.055233   47.860231           11.0     26
# 9990  15233           1    3.0   57.373889   39.688445            5.0      2
# 9991  11553           3    3.0  101.622794   51.628780           12.0     18
# 9992  14333         150    3.0   78.249637   49.385096           10.0      5
# 9993     48          13    3.0   80.631333   48.899083           10.0     11
# 9994   4158          23    2.0   64.864198         NaN            1.0     17
# 9995     77          32    2.0   50.401785   30.476203            5.0      6
# 9996   6159          18    1.0   41.521546   20.539216            9.0     13
# 9997   5123          27    1.0   47.939008         NaN            1.0     12
# 9998   5400          75    2.0   43.602562   33.840147            8.0      1
# 9999   6306         128    1.0   38.666645   21.157874            8.0      7
#
#       HouseFloor  HouseYear     Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 0            9.0       1969  8.903972e-02         B         B        33
# 1            9.0       1978  6.998930e-05         B         B        46
# 2           12.0       1968  4.963726e-02         B         B        34
# 3           17.0       1977  4.378852e-01         B         B        23
# 4           12.0       1976  1.233889e-02         B         B        35
# 5           17.0       2011  3.094791e-01         B         B        35
# 6            5.0       1960  4.605564e-01         B         B        20
# 7            0.0       1977  7.577876e-02         B         B         6
# 8           17.0       1977  7.122317e-03         B         B         1
# 9           17.0       2014  7.577876e-02         B         B         6
# 10           9.0       1973  1.185374e-01         B         B        30
# 11           8.0       1959  0.000000e+00         B         B        23
# 12          12.0       1999  9.079910e-02         B         B        74
# 13          12.0       1980  1.332153e-01         B         B        49
# 14           4.0       1977  7.215758e-02         B         B         2
# 15           9.0       1979  3.717782e-02         B         B        52
# 16           5.0       1983  5.181543e-02         B         B         5
# 17          14.0       2001  6.975336e-02         B         B        53
# 18          12.0       1983  1.332153e-01         B         B        49
# 19          25.0       2012  9.913630e-04         B         B        33
# 20          17.0       2002  3.198094e-01         B         B        25
# 21           1.0       1977  2.114012e-01         B         B         9
# 22          22.0       1996  4.112463e-02         B         B        46
# 23           0.0       1977  6.076152e-03         B         B        30
# 24           5.0       1964  2.074133e-02         B         B        24
# 25          17.0       1977  7.577876e-02         B         B         6
# 26           0.0       2018  7.215758e-02         B         B         2
# 27          17.0       1977  7.577876e-02         B         B         6
# 28           9.0       2014  3.465608e-02         B         B         0
# 29           9.0       1972  1.696760e-04         B         B        36
# ...          ...        ...           ...       ...       ...       ...
# 9970         9.0       1970  1.496664e-01         B         B        22
# 9971        17.0       1989  1.004557e-01         B         B        43
# 9972        17.0       1977  2.432045e-01         B         B         5
# 9973        14.0       1972  1.800000e-09         B         B        16
# 9974         4.0       2016  7.815280e-05         B         B        22
# 9975        15.0       1977  7.215758e-02         B         B         2
# 9976        17.0       1977  1.185374e-01         B         B        30
# 9977        12.0       1970  6.076152e-03         B         B        30
# 9978        17.0       1977  7.122317e-03         B         B         1
# 9979        17.0       1988  1.356498e-01         B         B        46
# 9980         9.0       1972  2.827977e-01         B         B        33
# 9981        12.0       1977  6.998930e-05         B         B        46
# 9982        12.0       1968  4.378852e-01         B         B        23
# 9983        17.0       2015  2.432045e-01         B         B         5
# 9984         9.0       1983  3.711490e-01         B         B        34
# 9985         1.0       1977  2.114012e-01         B         B         9
# 9986        22.0       1977  7.122317e-03         B         B         1
# 9987         4.0       1977  3.465608e-02         B         B         0
# 9988        23.0       1987  4.963726e-02         B         B        34
# 9989        24.0       2005  4.111635e-02         B         B        53
# 9990         5.0       1962  3.627009e-02         B         B         6
# 9991        17.0       2000  2.650887e-01         B         B        37
# 9992        16.0       1976  3.003225e-01         B         B        52
# 9993        14.0       1999  9.079910e-02         B         B        74
# 9994        17.0       1977  7.577876e-02         B         B         6
# 9995         5.0       1968  1.356498e-01         B         B        46
# 9996        13.0       2000  0.000000e+00         B         B        30
# 9997        16.0       2015  7.215758e-02         B         B         2
# 9998         5.0       1961  3.074667e-01         B         A        30
# 9999        17.0       1990  0.000000e+00         B         B        27
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 0         7976         5           NaN            0       11       B
# 1        10309         1         240.0            1       16       B
# 2         7759         0         229.0            1        3       B
# 3         5735         3        1084.0            0        5       B
# 4         5776         1        2078.0            2        4       B
# 5         7715         4         990.0            0        6       B
# 6         4386        14           NaN            1        5       B
# 7         1437         3           NaN            0        2       B
# 8          264         0           NaN            0        1       B
# 9         1437         3           NaN            0        2       B
# 10        6207         1        1183.0            1        0       B
# 11        3684         2           NaN            0        4       B
# 12       19083         2           NaN            5       15       B
# 13       11395         3        1406.0            3        4       A
# 14         629         1           NaN            0        0       A
# 15       11217         1        2300.0            1        7       B
# 16        1227         0           NaN            0        0       B
# 17       13670         4           NaN            1       11       B
# 18       11395         3        1406.0            3        4       A
# 19        6783         3           NaN            1        9       B
# 20        4756        16        2857.0            5        8       B
# 21        1892         0           NaN            0        1       B
# 22        9515         5           NaN            1       10       B
# 23        5285         0         645.0            6        6       B
# 24        5613         5        1340.0            2        5       B
# 25        1437         3           NaN            0        2       B
# 26         629         1           NaN            0        0       A
# 27        1437         3           NaN            0        2       B
# 28         168         0           NaN            0        0       B
# 29        5992         0           NaN            1        1       B
# ...        ...       ...           ...          ...      ...     ...
# 9970      4789         2        4087.0            4        1       B
# 9971      7227         0           NaN            1        6       A
# 9972      1564         0         540.0            0        0       B
# 9973      3681        73        1815.0            2        5       B
# 9974      6398       141        1046.0            3       23       B
# 9975       629         1           NaN            0        0       A
# 9976      6207         1        1183.0            1        0       B
# 9977      5285         0         645.0            6        6       B
# 9978       264         0           NaN            0        1       B
# 9979      7960         6         350.0            3       11       B
# 9980      8667         2           NaN            0        6       B
# 9981     10309         1         240.0            1       16       B
# 9982      5735         3        1084.0            0        5       B
# 9983      1564         0         540.0            0        0       B
# 9984      7065         1         750.0            2        5       B
# 9985      1892         0           NaN            0        1       B
# 9986       264         0           NaN            0        1       B
# 9987       168         0           NaN            0        0       B
# 9988      7759         0         229.0            1        3       B
# 9989     14892         4           NaN            1        4       B
# 9990      1318         1         200.0            1        1       B
# 9991      5288         0        1937.0            3        2       B
# 9992     10311         6           NaN            1        9       B
# 9993     19083         2           NaN            5       15       B
# 9994      1437         3           NaN            0        2       B
# 9995      7960         6         350.0            3       11       B
# 9996      5562         0           NaN            0        5       A
# 9997       629         1           NaN            0        0       A
# 9998      5048         9         325.0            2        5       B
# 9999      4798         0          30.0            2        8       B
#
#               Price
# 0     184966.930730
# 1     300009.450063
# 2     220925.908524
# 3     175616.227217
# 4     150226.531644
# 5     215898.447742
# 6     296021.204377
# 7     221244.156664
# 8     229102.795999
# 9      95380.220993
# 10    204243.553129
# 11    165534.541425
# 12    229220.372609
# 13    252481.908323
# 14    140647.565937
# 15     89084.327876
# 16    117000.381287
# 17    231828.437667
# 18    183743.230464
# 19    394895.325987
# 20    521919.057400
# 21    127200.026511
# 22    215083.969056
# 23    571069.052600
# 24    241718.099527
# 25    244145.827069
# 26    337299.867936
# 27    173910.923723
# 28     95338.198549
# 29    213374.166403
# ...             ...
# 9970  220804.817110
# 9971  228845.682509
# 9972  222068.370598
# 9973  197405.312185
# 9974   65949.315881
# 9975  190325.071232
# 9976  175229.645872
# 9977  174497.101781
# 9978  185996.664227
# 9979  339230.931543
# 9980  203000.197806
# 9981  242356.408174
# 9982  177449.715863
# 9983  164356.212221
# 9984  226434.880156
# 9985   95529.569405
# 9986  200332.511658
# 9987  115797.553006
# 9988  261095.834383
# 9989  441108.911237
# 9990  163807.542987
# 9991  212883.501504
# 9992  342418.758888
# 9993  350684.628560
# 9994  171323.515653
# 9995  196684.316040
# 9996  189050.289571
# 9997  159143.805370
# 9998  181595.339808
# 9999  218714.077615
#
# [10000 rows x 20 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 20 columns):
# Id               10000 non-null int64
# DistrictId       10000 non-null int64
# Rooms            10000 non-null float64
# Square           10000 non-null float64
# LifeSquare       7887 non-null float64
# KitchenSquare    10000 non-null float64
# Floor            10000 non-null int64
# HouseFloor       10000 non-null float64
# HouseYear        10000 non-null int64
# Ecology_1        10000 non-null float64
# Ecology_2        10000 non-null object
# Ecology_3        10000 non-null object
# Social_1         10000 non-null int64
# Social_2         10000 non-null int64
# Social_3         10000 non-null int64
# Healthcare_1     5202 non-null float64
# Helthcare_2      10000 non-null int64
# Shops_1          10000 non-null int64
# Shops_2          10000 non-null object
# Price            10000 non-null float64
# dtypes: float64(8), int64(9), object(3)
# memory usage: 1.5+ MB

# %%
dataset.HouseYear.min()
# Out:
# 1910

# %%
def reduce_mem_usage(df):
    """ iterate through all the columns of a dataframe and modify the data type
        to reduce memory usage.        
    """
    start_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage of dataframe is {:.2f} MB'.format(start_mem))
    
    for col in df.columns:
        col_type = df[col].dtype
        
        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        else:
            df[col] = df[col].astype('category')

    end_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage after optimization is: {:.2f} MB'.format(end_mem))
    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))
    
    return df

# %%
dataset = reduce_mem_usage(dataset)
dataset.info()
# Out:
# Memory usage of dataframe is 1.53 MB
# Memory usage after optimization is: 0.35 MB
# Decreased by 76.9%
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 20 columns):
# Id               10000 non-null int16
# DistrictId       10000 non-null int16
# Rooms            10000 non-null float16
# Square           10000 non-null float16
# LifeSquare       7887 non-null float16
# KitchenSquare    10000 non-null float16
# Floor            10000 non-null int8
# HouseFloor       10000 non-null float16
# HouseYear        10000 non-null int32
# Ecology_1        10000 non-null float16
# Ecology_2        10000 non-null category
# Ecology_3        10000 non-null category
# Social_1         10000 non-null int8
# Social_2         10000 non-null int16
# Social_3         10000 non-null int16
# Healthcare_1     5202 non-null float16
# Helthcare_2      10000 non-null int8
# Shops_1          10000 non-null int8
# Shops_2          10000 non-null category
# Price            10000 non-null float32
# dtypes: category(3), float16(7), float32(1), int16(4), int32(1), int8(4)
# memory usage: 361.7 KB

# %%
dataset.columns
# Out:
# Index(['Id', 'DistrictId', 'Rooms', 'Square', 'LifeSquare', 'KitchenSquare',
#        'Floor', 'HouseFloor', 'HouseYear', 'Ecology_1', 'Ecology_2',
#        'Ecology_3', 'Social_1', 'Social_2', 'Social_3', 'Healthcare_1',
#        'Helthcare_2', 'Shops_1', 'Shops_2', 'Price'],
#       dtype='object')

# %%
dataset[dataset.Rooms == 0].count().Id
# Out:
# 8

# %%
# Проверим есть ли  среди комнат не целое число
dataset[dataset.Rooms % 1 != 0].count().Id
# Out:
# 0

# %%
dataset.Rooms.unique()
# Out:
# array([ 2.,  3.,  1.,  4., 10.,  0.,  5., 19.,  6.])

# %%
dataset.Rooms = dataset.Rooms.astype(np.int8)

# %%
dataset.Rooms.dtype
# Out:
# dtype('int8')

# %%
dataset['HouseAge'] = 2020 - dataset['HouseYear']
dataset['HouseAge'].head(10)
# Out:
# 0    51
# 1    42
# 2    52
# 3    43
# 4    44
# 5     9
# 6    60
# 7    43
# 8    43
# 9     6
# Name: HouseAge, dtype: int32

# %%
dataset['HouseAge'].mean(), dataset['HouseAge'].max(), dataset['HouseAge'].min()
# Out:
# (-1970.1663, 110, -20049991)

# %%
dataset[dataset['HouseAge'] == 0].count().Id
# Out:
# 19

# %%
dataset[dataset['HouseAge'] < 0].count().Id
# Out:
# 2

# %%
# изменяем отрицательный возраст домов на 0
dataset.loc[dataset['HouseAge'] < 0, 'HouseAge'] = 0

# %%
dataset[dataset['HouseAge'] == 0].count().Id
# Out:
# 21

# %%
dataset['HouseAge'].mean()
# Out:
# 35.1276

# %%
plt.figure(figsize = (16, 8))
sns.distplot(dataset['Price'], bins=100)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
ds_features = dataset.drop(['Id', 'Price'], axis=1)

# %%
ds_features.hist(figsize=(16,16), bins=20, grid=False);

# %%
grid = sns.jointplot(dataset['Price'], dataset['HouseAge'], kind='reg')
grid.fig.set_figwidth(16)
grid.fig.set_figheight(8)

plt.show()

# %% [markdown]
# ### Из графика выше напрямую зависимость цены от возраста домов не наблюдается

# %%
dataset.DistrictId.unique()
# Out:
# array([ 35,  41,  53,  58,  99,  59, 154,  74,   1,  23,  28,  31,  13,
#         57,  27,  85,  34,  19,   0,  48,  54, 150,  11,  50,  61,  44,
#         90, 200,  43, 177, 101,  38,  21, 103,  98, 170,  94,   5,  88,
#         47,   6,  52,  62,  77,  79,   9, 156,  69, 108,  96, 169,  18,
#        148, 128,  10, 144, 120,  39,   7,  84, 123, 159,  70, 129,   3,
#         95,  78,  45,  15, 121,  49,  25,   2, 127,  56, 109,  46,  17,
#        119,  80,  86,  83, 137,  91,  92, 118, 187,  36, 106, 161,  22,
#         63, 167, 113,  66,  29,  37,  20,   8, 181,  40,  93,  30,  81,
#        107, 130, 100,  12, 125,  67,  26,  89,  24, 111, 138,  64, 124,
#        183,  55, 157, 151,  33,  87, 126, 155, 164, 105, 110, 132,  71,
#         73, 189,  75, 122, 163, 141,  76, 115, 139, 143, 201, 165, 190,
#        193, 174,  60, 114, 172, 134, 117, 149, 153, 131, 145,  82, 160,
#         42,  32, 133, 208, 171, 176, 173, 147,  97, 142, 195, 180, 196,
#        112,  72, 175,   4, 186, 146, 191, 168, 192,  14, 199, 136, 162,
#        179, 188, 135, 140,  16,  51, 178, 104,  68, 152, 194, 116, 207,
#        185,  65, 102, 166, 182, 202, 184, 205, 209, 158], dtype=int64)

# %%
grid = sns.jointplot(dataset['Price'], dataset['DistrictId'], kind='reg')
grid.fig.set_figwidth(16)
grid.fig.set_figheight(8)

plt.show()

# %% [markdown]
# ### Из графика выше напрямую зависимость цены от района не наблюдается

# %%
grid = sns.jointplot(dataset['Price'], dataset['Rooms'], kind='reg')
grid.fig.set_figwidth(16)
grid.fig.set_figheight(8)

plt.show()

# %% [markdown]
# ### Выбросы значений комнат 19, 10, 6, 0

# %%
dataset.Rooms.median()
# Out:
# 2.0

# %%
dataset.loc[dataset.Rooms > 5, 'Rooms'] = dataset.Rooms.median()

# %%
dataset.loc[dataset.Rooms == 0, 'Rooms'] = dataset.Rooms.median()

# %%
grid = sns.jointplot(dataset['Price'], dataset['Rooms'], kind='reg')
grid.fig.set_figwidth(16)
grid.fig.set_figheight(8)

plt.show()

# %% [markdown]
# ### В целом заметна корреляция между ценой и количеством комнат

# %%
dataset.LifeSquare.hist(figsize=(16, 8), bins=1000, grid=False);

# %% [markdown]
# ### Присутствует огромный выброс

# %%
dataset.LifeSquare.min()
# Out:
# 0.3706

# %%
dataset.LifeSquare.max()
# Out:
# 7480.0

# %%
dataset.LifeSquare.mean()
# Out:
# inf

# %%
dataset.LifeSquare.median()
# Out:
# 32.78

# %%
dataset.LifeSquare.count()
# Out:
# 7887

# %%
dataset[dataset.LifeSquare > 100].count()
# Out:
# Id               62
# DistrictId       62
# Rooms            62
# Square           62
# LifeSquare       62
# KitchenSquare    62
# Floor            62
# HouseFloor       62
# HouseYear        62
# Ecology_1        62
# Ecology_2        62
# Ecology_3        62
# Social_1         62
# Social_2         62
# Social_3         62
# Healthcare_1     23
# Helthcare_2      62
# Shops_1          62
# Shops_2          62
# Price            62
# HouseAge         62
# dtype: int64

# %%
df_1room = dataset[dataset.Rooms == 1]
df_2room = dataset[dataset.Rooms == 2]
df_3room = dataset[dataset.Rooms == 3]
df_4room = dataset[dataset.Rooms == 4]
df_5room = dataset[dataset.Rooms == 5]

df_1room.head(10)
# Out:
#        Id  DistrictId  Rooms    Square  LifeSquare  KitchenSquare  Floor  \
# 4   10783          99    1.0  39.65625   23.781250            7.0     11
# 9    8649          23    1.0  46.46875   18.921875            8.0     13
# 14  10953          27    1.0  53.78125   52.406250            1.0      5
# 18   2829          57    1.0  44.50000   23.109375            8.0      6
# 22  11852          48    1.0  41.65625   20.203125           10.0     19
# 28   8054          23    1.0  42.53125   43.968750            1.0      3
# 31   4785          61    1.0  41.75000   19.343750            9.0     12
# 33  13905          44    1.0  34.78125   18.203125            6.0      7
# 36  11703          23    1.0  41.12500         NaN            1.0      4
# 47  14292         103    1.0  41.53125   23.296875            8.0      7
#
#     HouseFloor  HouseYear  Ecology_1  ... Ecology_3 Social_1  Social_2  \
# 4         12.0       1976   0.012337  ...         B       35      5776
# 9         17.0       2014   0.075806  ...         B        6      1437
# 14         4.0       1977   0.072144  ...         B        2       629
# 18        12.0       1983   0.133179  ...         B       49     11395
# 22        22.0       1996   0.041138  ...         B       46      9515
# 28         9.0       2014   0.034668  ...         B        0       168
# 31        16.0       1984   0.300293  ...         B       52     10311
# 33         9.0       1972   0.036133  ...         B       24      4378
# 36        17.0       1977   0.075806  ...         B        6      1437
# 47        16.0       1981   0.014420  ...         B       19      3806
#
#     Social_3  Healthcare_1  Helthcare_2  Shops_1  Shops_2          Price  \
# 4          1        2078.0            2        4        B  150226.531250
# 9          3           NaN            0        2        B   95380.218750
# 14         1           NaN            0        0        A  140647.562500
# 18         3        1406.0            3        4        A  183743.234375
# 22         5           NaN            1       10        B  215083.968750
# 28         0           NaN            0        0        B   95338.195312
# 31         6           NaN            1        9        B  189007.234375
# 33         0        1036.0            1        1        B  154928.812500
# 36         3           NaN            0        2        B  103510.226562
# 47         4           NaN            0        3        B  234052.265625
#
#     HouseAge
# 4         44
# 9          6
# 14        43
# 18        37
# 22        24
# 28         6
# 31        36
# 33        48
# 36        43
# 47        39
#
# [10 rows x 21 columns]

# %%
df_1room.LifeSquare.min(), df_1room.LifeSquare.max(), df_1room.LifeSquare.median()
# Out:
# (0.3706, 410.8, 21.66)

# %%
df_1room.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3705 entries, 4 to 9999
# Data columns (total 21 columns):
# Id               3705 non-null int16
# DistrictId       3705 non-null int16
# Rooms            3705 non-null float64
# Square           3705 non-null float16
# LifeSquare       2827 non-null float16
# KitchenSquare    3705 non-null float16
# Floor            3705 non-null int8
# HouseFloor       3705 non-null float16
# HouseYear        3705 non-null int32
# Ecology_1        3705 non-null float16
# Ecology_2        3705 non-null category
# Ecology_3        3705 non-null category
# Social_1         3705 non-null int8
# Social_2         3705 non-null int16
# Social_3         3705 non-null int16
# Healthcare_1     1804 non-null float16
# Helthcare_2      3705 non-null int8
# Shops_1          3705 non-null int8
# Shops_2          3705 non-null category
# Price            3705 non-null float32
# HouseAge         3705 non-null int32
# dtypes: category(3), float16(6), float32(1), float64(1), int16(4), int32(2), int8(4)
# memory usage: 199.3 KB

# %%
df_1room.LifeSquare.hist(figsize=(16, 8), bins=100, grid=False);

# %%
def sns_x_y(x, y):
    grid = sns.jointplot(x, y, kind='reg')
    grid.fig.set_figwidth(16)
    grid.fig.set_figheight(8)

    plt.show()

# %%
sns_x_y(df_1room['Price'], df_1room['LifeSquare'])

# %%
df_1room.loc[df_1room['LifeSquare'] >= 100, 'LifeSquare'] = df_1room.LifeSquare.median()
df_1room.loc[df_1room['LifeSquare'] < 10, 'LifeSquare'] = df_1room.LifeSquare.median()

# %%
sns_x_y(df_1room['Price'], df_1room['LifeSquare'])

# %%
df_1room.LifeSquare.hist(figsize=(16, 8), bins=100, grid=False);

# %%
df_2room.LifeSquare.min(), df_2room.LifeSquare.max(), df_2room.LifeSquare.median()
# Out:
# (0.7954, 638.0, 32.56)

# %%
df_2room.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3892 entries, 0 to 9998
# Data columns (total 21 columns):
# Id               3892 non-null int16
# DistrictId       3892 non-null int16
# Rooms            3892 non-null float64
# Square           3892 non-null float16
# LifeSquare       3061 non-null float16
# KitchenSquare    3892 non-null float16
# Floor            3892 non-null int8
# HouseFloor       3892 non-null float16
# HouseYear        3892 non-null int32
# Ecology_1        3892 non-null float16
# Ecology_2        3892 non-null category
# Ecology_3        3892 non-null category
# Social_1         3892 non-null int8
# Social_2         3892 non-null int16
# Social_3         3892 non-null int16
# Healthcare_1     2109 non-null float16
# Helthcare_2      3892 non-null int8
# Shops_1          3892 non-null int8
# Shops_2          3892 non-null category
# Price            3892 non-null float32
# HouseAge         3892 non-null int32
# dtypes: category(3), float16(6), float32(1), float64(1), int16(4), int32(2), int8(4)
# memory usage: 209.3 KB

# %%
sns_x_y(df_2room['Price'], df_2room['LifeSquare'])

# %%
df_2room.loc[df_2room['LifeSquare'] >= 100, 'LifeSquare'] = df_2room.LifeSquare.median()
df_2room.loc[df_2room['LifeSquare'] < 20, 'LifeSquare'] = df_2room.LifeSquare.median()

# %%
sns_x_y(df_2room['Price'], df_2room['LifeSquare'])

# %%
df_3room.LifeSquare.min(), df_3room.LifeSquare.max(), df_3room.LifeSquare.median()
# Out:
# (0.6416, 7480.0, 46.97)

# %%
df_3room.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2235 entries, 1 to 9993
# Data columns (total 21 columns):
# Id               2235 non-null int16
# DistrictId       2235 non-null int16
# Rooms            2235 non-null float64
# Square           2235 non-null float16
# LifeSquare       1842 non-null float16
# KitchenSquare    2235 non-null float16
# Floor            2235 non-null int8
# HouseFloor       2235 non-null float16
# HouseYear        2235 non-null int32
# Ecology_1        2235 non-null float16
# Ecology_2        2235 non-null category
# Ecology_3        2235 non-null category
# Social_1         2235 non-null int8
# Social_2         2235 non-null int16
# Social_3         2235 non-null int16
# Healthcare_1     1193 non-null float16
# Helthcare_2      2235 non-null int8
# Shops_1          2235 non-null int8
# Shops_2          2235 non-null category
# Price            2235 non-null float32
# HouseAge         2235 non-null int32
# dtypes: category(3), float16(6), float32(1), float64(1), int16(4), int32(2), int8(4)
# memory usage: 120.3 KB

# %%
sns_x_y(df_3room['Price'], df_3room['LifeSquare'])

# %% [markdown]
# ### Офигенный выброс)

# %%
df_3room.loc[df_3room['LifeSquare'] >= 500, 'LifeSquare'] = df_3room.LifeSquare.median()

# %%
sns_x_y(df_3room['Price'], df_3room['LifeSquare'])

# %%
df_3room.loc[df_3room['LifeSquare'] >= 140, 'LifeSquare'] = df_3room.LifeSquare.median()
df_3room.loc[df_3room['LifeSquare'] < 30, 'LifeSquare'] = df_3room.LifeSquare.median()

# %%
sns_x_y(df_3room['Price'], df_3room['LifeSquare'])

# %%
df_4room.LifeSquare.min(), df_4room.LifeSquare.max(), df_4room.LifeSquare.median()
# Out:
# (1.452, 201.6, 64.94)

# %%
df_4room.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 150 entries, 77 to 9918
# Data columns (total 21 columns):
# Id               150 non-null int16
# DistrictId       150 non-null int16
# Rooms            150 non-null float64
# Square           150 non-null float16
# LifeSquare       141 non-null float16
# KitchenSquare    150 non-null float16
# Floor            150 non-null int8
# HouseFloor       150 non-null float16
# HouseYear        150 non-null int32
# Ecology_1        150 non-null float16
# Ecology_2        150 non-null category
# Ecology_3        150 non-null category
# Social_1         150 non-null int8
# Social_2         150 non-null int16
# Social_3         150 non-null int16
# Healthcare_1     86 non-null float16
# Helthcare_2      150 non-null int8
# Shops_1          150 non-null int8
# Shops_2          150 non-null category
# Price            150 non-null float32
# HouseAge         150 non-null int32
# dtypes: category(3), float16(6), float32(1), float64(1), int16(4), int32(2), int8(4)
# memory usage: 8.3 KB

# %%
sns_x_y(df_4room['Price'], df_4room['LifeSquare'])

# %%
df_4room.loc[df_4room['LifeSquare'] > 150, 'LifeSquare'] = df_4room.LifeSquare.median()
df_4room.loc[df_4room['LifeSquare'] < 35, 'LifeSquare'] = df_4room.LifeSquare.median()

# %%
sns_x_y(df_4room['Price'], df_4room['LifeSquare'])

# %%
df_5room.LifeSquare.min(), df_5room.LifeSquare.max(), df_5room.LifeSquare.median()
# Out:
# (39.4, 234.0, 80.5)

# %%
sns_x_y(df_5room['Price'], df_5room['LifeSquare'])

# %%
df_5room.loc[df_5room['LifeSquare'] > 200, 'LifeSquare'] = df_5room.LifeSquare.median()
df_5room.loc[df_5room['LifeSquare'] < 50, 'LifeSquare'] = df_5room.LifeSquare.median()

# %%
sns_x_y(df_5room['Price'], df_5room['LifeSquare'])

# %%
df_1room.LifeSquare = df_1room.LifeSquare.fillna(df_1room.LifeSquare.median())
df_1room.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3705 entries, 4 to 9999
# Data columns (total 21 columns):
# Id               3705 non-null int16
# DistrictId       3705 non-null int16
# Rooms            3705 non-null float64
# Square           3705 non-null float16
# LifeSquare       3705 non-null float16
# KitchenSquare    3705 non-null float16
# Floor            3705 non-null int8
# HouseFloor       3705 non-null float16
# HouseYear        3705 non-null int32
# Ecology_1        3705 non-null float16
# Ecology_2        3705 non-null category
# Ecology_3        3705 non-null category
# Social_1         3705 non-null int8
# Social_2         3705 non-null int16
# Social_3         3705 non-null int16
# Healthcare_1     1804 non-null float16
# Helthcare_2      3705 non-null int8
# Shops_1          3705 non-null int8
# Shops_2          3705 non-null category
# Price            3705 non-null float32
# HouseAge         3705 non-null int32
# dtypes: category(3), float16(6), float32(1), float64(1), int16(4), int32(2), int8(4)
# memory usage: 199.3 KB

# %%
df_2room.LifeSquare = df_2room.LifeSquare.fillna(df_2room.LifeSquare.median())
df_3room.LifeSquare = df_3room.LifeSquare.fillna(df_3room.LifeSquare.median())
df_4room.LifeSquare = df_4room.LifeSquare.fillna(df_4room.LifeSquare.median())
df_5room.LifeSquare = df_5room.LifeSquare.fillna(df_5room.LifeSquare.median())

# %%
df = pd.concat([df_1room, df_2room, df_3room, df_4room, df_5room])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10000 entries, 4 to 9699
# Data columns (total 21 columns):
# Id               10000 non-null int16
# DistrictId       10000 non-null int16
# Rooms            10000 non-null float64
# Square           10000 non-null float16
# LifeSquare       10000 non-null float16
# KitchenSquare    10000 non-null float16
# Floor            10000 non-null int8
# HouseFloor       10000 non-null float16
# HouseYear        10000 non-null int32
# Ecology_1        10000 non-null float16
# Ecology_2        10000 non-null category
# Ecology_3        10000 non-null category
# Social_1         10000 non-null int8
# Social_2         10000 non-null int16
# Social_3         10000 non-null int16
# Healthcare_1     5202 non-null float16
# Helthcare_2      10000 non-null int8
# Shops_1          10000 non-null int8
# Shops_2          10000 non-null category
# Price            10000 non-null float32
# HouseAge         10000 non-null int32
# dtypes: category(3), float16(6), float32(1), float64(1), int16(4), int32(2), int8(4)
# memory usage: 537.4 KB

# %%
df.Helthcare_2.unique()
# Out:
# array([2, 0, 3, 1, 4, 5, 6], dtype=int64)

# %%
df.Healthcare_1.unique()
# Out:
# array([2078.,   nan, 1406., 1036., 1450., 1183.,  540.,  240., 2300.,
#         125.,  730., 1937.,  165., 1340.,  192.,   46., 3300.,  750.,
#        4508., 3856.,  705.,   30., 1308., 4088., 1130.,  620.,  262.,
#         990., 1020., 1084.,  562.,  229., 1322., 1547., 2644., 1430.,
#        1548., 1970., 1046.,  145., 1940., 2728.,  645.,   75., 4128.,
#        1145.,  628.,  900., 1015., 1894.,   35.,  200.,  770., 4704.,
#        2716.,  370., 1786.,  830.,  325.,  350., 2856.,  320., 1575.,
#        2672.,  800., 2890.,  176.,  520.,   80., 2620., 2500., 4848.,
#         100.,   32., 1994.,  810., 1815.,  920.,    0.])

# %%
sns_x_y(df['Price'], df['Healthcare_1'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10000 entries, 4 to 9699
# Data columns (total 21 columns):
# Id               10000 non-null int16
# DistrictId       10000 non-null int16
# Rooms            10000 non-null float64
# Square           10000 non-null float16
# LifeSquare       10000 non-null float16
# KitchenSquare    10000 non-null float16
# Floor            10000 non-null int8
# HouseFloor       10000 non-null float16
# HouseYear        10000 non-null int32
# Ecology_1        10000 non-null float16
# Ecology_2        10000 non-null category
# Ecology_3        10000 non-null category
# Social_1         10000 non-null int8
# Social_2         10000 non-null int16
# Social_3         10000 non-null int16
# Healthcare_1     5202 non-null float16
# Helthcare_2      10000 non-null int8
# Shops_1          10000 non-null int8
# Shops_2          10000 non-null category
# Price            10000 non-null float32
# HouseAge         10000 non-null int32
# dtypes: category(3), float16(6), float32(1), float64(1), int16(4), int32(2), int8(4)
# memory usage: 537.4 KB

# %%
sns_x_y(df['DistrictId'], df['Healthcare_1'])

# %%
df['Healthcare_1'].min(), df['Healthcare_1'].max(), df['Healthcare_1'].mean(), df['Healthcare_1'].median()
# Out:
# (0.0, 4850.0, inf, 900.0)

# %%
df.Healthcare_1 = df.Healthcare_1.fillna(df.Healthcare_1.median())
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10000 entries, 4 to 9699
# Data columns (total 21 columns):
# Id               10000 non-null int16
# DistrictId       10000 non-null int16
# Rooms            10000 non-null float64
# Square           10000 non-null float16
# LifeSquare       10000 non-null float16
# KitchenSquare    10000 non-null float16
# Floor            10000 non-null int8
# HouseFloor       10000 non-null float16
# HouseYear        10000 non-null int32
# Ecology_1        10000 non-null float16
# Ecology_2        10000 non-null category
# Ecology_3        10000 non-null category
# Social_1         10000 non-null int8
# Social_2         10000 non-null int16
# Social_3         10000 non-null int16
# Healthcare_1     10000 non-null float16
# Helthcare_2      10000 non-null int8
# Shops_1          10000 non-null int8
# Shops_2          10000 non-null category
# Price            10000 non-null float32
# HouseAge         10000 non-null int32
# dtypes: category(3), float16(6), float32(1), float64(1), int16(4), int32(2), int8(4)
# memory usage: 537.4 KB

# %%
sns_x_y(df['Price'], df['Shops_1'])

# %%
df['Shops_2'].unique()
# Out:
# [B, A]
# Categories (2, object): [B, A]
